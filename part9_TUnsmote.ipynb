# %% [markdown]
# <a href="https://colab.research.google.com/github/jnsbrdbr/thesis/blob/thesis/part9_TUnsmote.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import jaccard_score
from scipy.spatial.distance import pdist, squareform

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
store = pd.HDFStore('/content/drive/MyDrive/1000/Tdata.h5')

adj=store['adj']
store.close()

# %%
store = pd.HDFStore('/content/drive/MyDrive/1000/TCFdf.h5')
CF=store['CFdf']
store.close()
#with pd.HDFStore('/content/drive/MyDrive/1000/TCFdf.h5',  mode='r') as newstore:
#    CF = newstore.select('CFdf')

# %%
store = pd.HDFStore('/content/drive/MyDrive/1000/TTFdf.h5')
TF=store['TFdf']
store.close()
#with pd.HDFStore('/content/drive/MyDrive/1000/TTFdf.h5',  mode='r') as newstore:
#    TF = newstore.select('TFdf')

# %%
with pd.HDFStore('/content/drive/MyDrive/1000/TjaccardsimilaritydfR.h5',  mode='r') as newstore:
    jaccardsimilarity = newstore.select('jaccardsimilaritydfR')

# %%
store = pd.HDFStore('/content/drive/MyDrive/1000/TcosinesimilaritydfR.h5')
cosine=store['cosine_similaritydfR']

# %%
store = pd.HDFStore('/content/drive/MyDrive/1000/TL1normdf.h5')
L1_normdf=store['L1_normdf']
store.close()

# %%
store = pd.HDFStore('/content/drive/MyDrive/1000/Tsum.h5')
wsumdf=store['wsumdf']
store.close()

# %%
with pd.HDFStore('/content/drive/MyDrive/1000/Tmul.h5',  mode='r') as newstore:
    wmuldf = newstore.select('wmuldf')

# %%
#store = pd.HDFStore('/content/drive/MyDrive/1000/TLdata.h5')
#adjl=store['adjl']
#store.close()
with pd.HDFStore('/content/drive/MyDrive/1000/TLdata.h5',  mode='r') as newstore:
    adjl = newstore.select('adjl')

# %% [markdown]
# # **PCa**

# %%
from sklearn.decomposition import PCA


pca = PCA(n_components=10)
CF_pca = pca.fit_transform(CF)
CF_pca_df=pd.DataFrame(CF_pca)

# %%
CF_pca_df
# Out:
#             0         1         2  ...         7             8             9
# 0   -1.715972 -3.099936 -0.041249  ...  3.341114 -1.686507e-13  1.170480e-13
# 1   -1.715972 -3.099936 -0.041249  ...  3.341114 -1.580929e-14 -2.270813e-14
# 2   -1.715972 -3.099936 -0.041249  ...  3.341114 -2.688831e-14  5.724075e-14
# 3   -1.715972 -3.099936 -0.041249  ...  3.341114 -1.129018e-13  1.255431e-14
# 4   -1.715972 -3.099936 -0.041249  ...  3.341114 -2.431112e-13  1.460192e-14
# ..        ...       ...       ...  ...       ...           ...           ...
# 995 -2.114893 -4.572474 -0.754679  ... -0.063010  8.110705e-03  1.191836e-02
# 996 -2.114893 -4.572474 -0.754679  ... -0.063010  6.128713e-02 -3.494290e-02
# 997 -2.114893 -4.572474 -0.754679  ... -0.063010 -6.589775e-02  1.887411e-02
# 998 -2.114893 -4.572474 -0.754679  ... -0.063010 -1.908545e-02 -6.223041e-03
# 999 -2.114893 -4.572474 -0.754679  ... -0.063010  4.489224e-02 -2.183394e-02
#
# [1000 rows x 10 columns]

# %%
pca = PCA(n_components=10)
TF_pca = pca.fit_transform(TF)
TF_pca_df=pd.DataFrame(TF_pca)

# %%
TF_pca_df
# Out:
#                0          1          2  ...         7         8         9
# 0     -26.167339   0.109748   0.187462  ... -0.002291 -1.817205 -0.021183
# 1     -26.167339   0.109748   0.187462  ... -0.002291 -1.817205 -0.021183
# 2     -26.167339   0.109748   0.187462  ... -0.002291 -1.817205 -0.021183
# 3     -26.167339   0.109748   0.187462  ... -0.002291 -1.817205 -0.021183
# 4    1393.385962 -11.935691 -29.759005  ...  0.884093 -1.749524 -0.183266
# ..           ...        ...        ...  ...       ...       ...       ...
# 995   -29.238191   0.128642   0.210675  ... -0.000867 -4.540979 -0.763937
# 996   -29.238191   0.128642   0.210675  ... -0.000867 -4.540979 -0.763937
# 997   -29.238191   0.128642   0.210675  ... -0.000867 -4.540979 -0.763937
# 998   -29.238191   0.128642   0.210675  ... -0.000867 -4.540979 -0.763937
# 999   -29.238191   0.128642   0.210675  ... -0.000867 -4.540979 -0.763937
#
# [1000 rows x 10 columns]

# %%
pca = PCA(n_components=10)
jaccard_similarity_pca = pca.fit_transform(jaccardsimilarity)
jaccard_similarity_pca_df=pd.DataFrame(jaccard_similarity_pca)

# %%
jaccard_similarity_pca_df
# Out:
#             0         1         2  ...         7             8             9
# 0   -1.715972 -3.099936 -0.041249  ...  3.341114 -8.714265e-15  1.707084e-13
# 1   -1.715972 -3.099936 -0.041249  ...  3.341114  1.363076e-13  8.499071e-14
# 2   -1.715972 -3.099936 -0.041249  ...  3.341114  9.022149e-14  1.526441e-13
# 3   -1.715972 -3.099936 -0.041249  ...  3.341114 -8.990660e-14  1.241262e-13
# 4   -1.715972 -3.099936 -0.041249  ...  3.341114  4.359518e-14  1.394181e-13
# ..        ...       ...       ...  ...       ...           ...           ...
# 995 -2.114893 -4.572474 -0.754679  ... -0.063010 -4.732423e-02 -6.626293e-03
# 996 -2.114893 -4.572474 -0.754679  ... -0.063010 -1.878074e-02  1.410811e-03
# 997 -2.114893 -4.572474 -0.754679  ... -0.063010 -1.904690e-02 -2.451132e-02
# 998 -2.114893 -4.572474 -0.754679  ... -0.063010 -5.265639e-05  2.667603e-02
# 999 -2.114893 -4.572474 -0.754679  ... -0.063010  4.924755e-03 -2.606666e-02
#
# [1000 rows x 10 columns]

# %%
pca = PCA(n_components=10)
cosine_similarity_pca = pca.fit_transform(cosine)
cosine_similarity_pca_df=pd.DataFrame(cosine_similarity_pca)

# %%
cosine_similarity_pca_df
# Out:
#             0         1         2  ...         7             8             9
# 0   -1.715972 -3.099936 -0.041249  ...  3.341114 -3.265402e-14  2.357173e-13
# 1   -1.715972 -3.099936 -0.041249  ...  3.341114  7.866852e-14 -7.532105e-14
# 2   -1.715972 -3.099936 -0.041249  ...  3.341114  1.137836e-13 -7.829209e-14
# 3   -1.715972 -3.099936 -0.041249  ...  3.341114 -4.483179e-14  1.429115e-13
# 4   -1.715972 -3.099936 -0.041249  ...  3.341114 -3.433230e-14  3.011050e-14
# ..        ...       ...       ...  ...       ...           ...           ...
# 995 -2.114893 -4.572474 -0.754679  ... -0.063010  3.727816e-02  1.030665e-02
# 996 -2.114893 -4.572474 -0.754679  ... -0.063010  8.041611e-03 -4.786980e-03
# 997 -2.114893 -4.572474 -0.754679  ... -0.063010  9.299751e-03  3.109303e-02
# 998 -2.114893 -4.572474 -0.754679  ... -0.063010 -1.163383e-02  7.922184e-03
# 999 -2.114893 -4.572474 -0.754679  ... -0.063010  7.036729e-04 -4.783208e-03
#
# [1000 rows x 10 columns]

# %%
pca = PCA(n_components=10)
L1_normdf_similarity_pca = pca.fit_transform(L1_normdf)
L1_normdf_similarity_pca_df=pd.DataFrame(L1_normdf_similarity_pca)

# %%
L1_normdf_similarity_pca_df
# Out:
#             0         1         2  ...         7             8             9
# 0   -1.715972 -3.099936 -0.041249  ...  3.341114 -2.114464e-14  1.061933e-14
# 1   -1.715972 -3.099936 -0.041249  ...  3.341114  1.368121e-13 -8.907798e-14
# 2   -1.715972 -3.099936 -0.041249  ...  3.341114  3.011201e-13 -9.396273e-14
# 3   -1.715972 -3.099936 -0.041249  ...  3.341114  6.041566e-14 -3.605662e-14
# 4   -1.715972 -3.099936 -0.041249  ...  3.341114 -3.733257e-14 -9.701224e-15
# ..        ...       ...       ...  ...       ...           ...           ...
# 995 -2.114893 -4.572474 -0.754679  ... -0.063010 -1.730312e-02  7.478210e-02
# 996 -2.114893 -4.572474 -0.754679  ... -0.063010 -5.501628e-02 -3.264179e-02
# 997 -2.114893 -4.572474 -0.754679  ... -0.063010  2.453711e-02 -1.026833e-02
# 998 -2.114893 -4.572474 -0.754679  ... -0.063010 -5.620209e-03  3.822745e-03
# 999 -2.114893 -4.572474 -0.754679  ... -0.063010 -5.033951e-03  1.602013e-02
#
# [1000 rows x 10 columns]

# %%
pca = PCA(n_components=10)
wsumdf_similarity_pca = pca.fit_transform(wsumdf)
wsumdf_similarity_pca_df=pd.DataFrame(wsumdf_similarity_pca)

# %%
wsumdf_similarity_pca_df
# Out:
#              0             1  ...             8             9
# 0    -0.158046 -3.515906e-02  ...  3.272855e-02  1.024143e-01
# 1    -0.158046  1.526103e-02  ...  5.545362e-02  6.902019e-02
# 2    -0.158046 -6.814045e-02  ... -3.094008e-02 -5.673731e-02
# 3    -0.158046 -4.689913e-02  ... -7.909991e-03 -8.481500e-02
# 4    17.554873 -9.714362e-14  ...  3.781151e-13 -3.618924e-13
# ..         ...           ...  ...           ...           ...
# 995  -0.158046 -1.370953e-02  ... -7.322401e-02  1.352427e-01
# 996  -0.158046 -8.982300e-02  ...  3.160747e-02  5.228986e-02
# 997  -0.158046  5.921618e-02  ... -7.568846e-02 -4.769005e-02
# 998  -0.158046  6.139797e-02  ... -3.149135e-02 -1.290722e-02
# 999  -0.158046  3.743785e-02  ... -3.663308e-02 -8.288941e-02
#
# [1000 rows x 10 columns]

# %%
pca = PCA(n_components=10)
wmuldf_similarity_pca = pca.fit_transform(wmuldf)
wmuldf_similarity_pca_df=pd.DataFrame(wmuldf_similarity_pca)

# %%
wmuldf_similarity_pca_df
# Out:
#              0             1  ...             8             9
# 0    -0.111385 -4.113897e-03  ... -1.043801e-02  3.632285e-03
# 1    -0.111385  1.219123e-02  ... -1.618638e-02 -9.485347e-03
# 2    -0.111385 -2.075634e-02  ... -6.823120e-03 -7.814483e-05
# 3    -0.111385 -1.163452e-03  ... -2.087077e-02 -1.476893e-02
# 4    12.371234 -1.267113e-14  ... -6.473446e-15  2.349239e-14
# ..         ...           ...  ...           ...           ...
# 995  -0.111385 -3.653647e-03  ...  4.037032e-03 -2.541436e-02
# 996  -0.111385 -9.176620e-03  ...  9.605512e-03 -2.488035e-03
# 997  -0.111385 -8.897784e-03  ... -1.042634e-02 -1.926318e-02
# 998  -0.111385 -3.562732e-02  ... -1.411281e-02  3.196109e-02
# 999  -0.111385 -6.153664e-04  ...  1.487759e-02 -9.256506e-03
#
# [1000 rows x 10 columns]

# %%
l=np.array(adjl['label'])
l_df=pd.DataFrame(l)

# %%
#concat
frames = [CF_pca_df, TF_pca_df, jaccard_similarity_pca_df,cosine_similarity_pca_df,
          L1_normdf_similarity_pca_df,wsumdf_similarity_pca_df,wmuldf_similarity_pca_df,l_df]
result = pd.concat(frames,axis=1)

# %%
result
# Out:
#             0         1         2  ...             8             9  0
# 0   -1.715972 -3.099936 -0.041249  ... -1.043801e-02  3.632285e-03  1
# 1   -1.715972 -3.099936 -0.041249  ... -1.618638e-02 -9.485347e-03  1
# 2   -1.715972 -3.099936 -0.041249  ... -6.823120e-03 -7.814483e-05  1
# 3   -1.715972 -3.099936 -0.041249  ... -2.087077e-02 -1.476893e-02  1
# 4   -1.715972 -3.099936 -0.041249  ... -6.473446e-15  2.349239e-14  1
# ..        ...       ...       ...  ...           ...           ... ..
# 995 -2.114893 -4.572474 -0.754679  ...  4.037032e-03 -2.541436e-02  1
# 996 -2.114893 -4.572474 -0.754679  ...  9.605512e-03 -2.488035e-03  1
# 997 -2.114893 -4.572474 -0.754679  ... -1.042634e-02 -1.926318e-02  1
# 998 -2.114893 -4.572474 -0.754679  ... -1.411281e-02  3.196109e-02  1
# 999 -2.114893 -4.572474 -0.754679  ...  1.487759e-02 -9.256506e-03  1
#
# [1000 rows x 71 columns]

# %%
with pd.HDFStore('/content/drive/MyDrive/1000/TUnsmote_result',  mode='w') as store:
      store.append('result', result,format='table')
